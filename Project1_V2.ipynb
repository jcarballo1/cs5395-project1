# %%
import pandas as pd

# %%
df = pd.read_csv("aggregate_population_data.csv")

# %%
df
# Out:
#             Entity Code  Year  Population (historical estimates)  \
# 0      Afghanistan  AFG  1800                            3280000
# 1      Afghanistan  AFG  1801                            3280000
# 2      Afghanistan  AFG  1802                            3280000
# 3      Afghanistan  AFG  1803                            3280000
# 4      Afghanistan  AFG  1804                            3280000
# ...            ...  ...   ...                                ...
# 46811     Zimbabwe  ZWE  2017                           14236599
# 46812     Zimbabwe  ZWE  2018                           14438812
# 46813     Zimbabwe  ZWE  2019                           14645473
# 46814     Zimbabwe  ZWE  2020                           14862927
# 46815     Zimbabwe  ZWE  2021                           15092171
#
#        Fertility rate (Complete Gapminder, v12) (2017)  Life expectancy  \
# 0                                                 7.00              NaN
# ...

# %%
df2 = df[df['Entity'] == "World"]

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Population (historical estimates), Fertility rate (Complete Gapminder, v12) (2017), Life expectancy, Mortality rate, infant (per 1,000 live births), Human Development Index (UNDP), Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018)), Estimates, 1950 - 2020: Annually interpolated demographic indicators - Population change (thousands), Medium fertility variant, 2020 - 2099: Annually interpolated demographic indicators - Population change (thousands), Sex ratio at birth (Chao et al. 2019)]
# Index: []

# %%
df3 = pd.read_csv("aggregate_hdi_indicators_with_population.csv")

# %%
df3
# Out:
#             Entity Code  Year  Population (historical estimates)  \
# 0      Afghanistan  AFG  1800                          3280000.0
# 1      Afghanistan  AFG  1801                          3280000.0
# 2      Afghanistan  AFG  1802                          3280000.0
# 3      Afghanistan  AFG  1803                          3280000.0
# 4      Afghanistan  AFG  1804                          3280000.0
# ...            ...  ...   ...                                ...
# 49729     Zimbabwe  ZWE  2017                         14236599.0
# 49730     Zimbabwe  ZWE  2018                         14438812.0
# 49731     Zimbabwe  ZWE  2019                         14645473.0
# 49732     Zimbabwe  ZWE  2020                         14862927.0
# 49733     Zimbabwe  ZWE  2021                         15092171.0
#
#        Fertility rate (Complete Gapminder, v12) (2017)  \
# 0                                                 7.00
# 1                                                 7.00
# ...

# %%
df4 = df3[df3['Entity'] == "World"]

# %%
df4
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Population (historical estimates), Fertility rate (Complete Gapminder, v12) (2017), Mortality rate, infant (per 1,000 live births), Life expectancy, Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018)), Expected Years of Schooling (years), GNI per capita, PPP (constant 2017 international $), Actual Human Development Index (UNDP)]
# Index: []
