# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("aggregate_hdi_indicators_with_population.csv")

# %%
df
# Out:
#             Entity Code  Year  Population (historical estimates)  \
# 0      Afghanistan  AFG  1800                          3280000.0
# 1      Afghanistan  AFG  1801                          3280000.0
# 2      Afghanistan  AFG  1802                          3280000.0
# 3      Afghanistan  AFG  1803                          3280000.0
# 4      Afghanistan  AFG  1804                          3280000.0
# ...            ...  ...   ...                                ...
# 49729     Zimbabwe  ZWE  2017                         14236599.0
# 49730     Zimbabwe  ZWE  2018                         14438812.0
# 49731     Zimbabwe  ZWE  2019                         14645473.0
# 49732     Zimbabwe  ZWE  2020                         14862927.0
# 49733     Zimbabwe  ZWE  2021                         15092171.0
#
#        Fertility rate (Complete Gapminder, v12) (2017)  \
# 0                                                 7.00
# 1                                                 7.00
# 2                                                 7.00
# 3                                                 7.00
# 4                                                 7.00
# ...                                                ...
# 49729                                             3.68
# 49730                                              NaN
# 49731                                              NaN
# 49732                                              NaN
# 49733                                              NaN
#
#        Mortality rate, infant (per 1,000 live births)  Life expectancy  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# ...                                               ...              ...
# 49729                                            4.05           60.812
# 49730                                            3.93           61.195
# 49731                                            3.84           61.490
# 49732                                             NaN              NaN
# 49733                                             NaN              NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                                8.2
# 49730                                                NaN
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Expected Years of Schooling (years)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
# 49732                                  NaN
# 49733                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Actual Human Development Index (UNDP)
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 49729                                  0.535
# 49730                                    NaN
# 49731                                    NaN
# 49732                                    NaN
# 49733                                    NaN
#
# [49734 rows x 11 columns]

# %%
# calculate HDI rate per year 

#life expectancy index
#<-- ([Life expectancy] - [Life Expectancy Minimum]) / ([Life Expectancy Goalpost] - [Life Expectancy Minimum])
# ([life expentance of country] - 20) / (85 - 20))

#education expectancy index
#((([Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))] 
# - [Mean Years of Schooling Minimum]) / ([Mean Years of Schooling Goalpost] - [Mean Years of Schooling Minimum])) + (([Expected Years of Schooling (years)] - [Expected Years of Schooling Minimum]) 
# / ([Expected Years of Schooling Goalpost] - [Expected Years of Schooling Minimum]))) / 2

#income expectancy index
# (LN([GNI per capita, PPP (constant 2017 international $)]) - LN([GNI per Capita Minimum])) 
# / (LN([GNI per Capita Goalpost]) - LN([GNI per Capita Minimum]))

#HDI
# ([Calculated Life Expectancy Index] * [Calculated Education Index] * [Calculated GNI per Capita Index]) ^ (1/3)


# find life expectancy weight for each country (life expectancy/global life expetancy)
# apply weight to life expectany (weight (^) * life expectancy)
# create new column to store
# use all countries weighted life expectancies to get global life expectancy
# do with other factors
# find gobal HDI

# %%
factors = df.drop(columns = ['Fertility rate (Complete Gapminder, v12) (2017)', 'Mortality rate, infant (per 1,000 live births)', 'Code'])

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 0      Afghanistan  1800                          3280000.0              NaN
# 1      Afghanistan  1801                          3280000.0              NaN
# 2      Afghanistan  1802                          3280000.0              NaN
# 3      Afghanistan  1803                          3280000.0              NaN
# 4      Afghanistan  1804                          3280000.0              NaN
# ...            ...   ...                                ...              ...
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
# 49732     Zimbabwe  2020                         14862927.0              NaN
# 49733     Zimbabwe  2021                         15092171.0              NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                                8.2
# 49730                                                NaN
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Expected Years of Schooling (years)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
# 49732                                  NaN
# 49733                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Actual Human Development Index (UNDP)
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 49729                                  0.535
# 49730                                    NaN
# 49731                                    NaN
# 49732                                    NaN
# 49733                                    NaN
#
# [49734 rows x 8 columns]

# %%
#factors = factors.set_index('Entity')

# %%
factors = factors.dropna(thresh=4)

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 75     Afghanistan  1875                          4247357.0              NaN
# 80     Afghanistan  1880                          4354370.0              NaN
# 85     Afghanistan  1885                          4464010.0              NaN
# 90     Afghanistan  1890                          4576341.0              NaN
# ...            ...   ...                                ...              ...
# 49727     Zimbabwe  2015                         13814642.0           59.534
# 49728     Zimbabwe  2016                         14030338.0           60.294
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 75                                                  0.01
# 80                                                  0.01
# 85                                                  0.01
# 90                                                  0.01
# ...                                                  ...
# 49727                                               8.20
# 49728                                               8.20
# 49729                                               8.20
# 49730                                                NaN
# 49731                                                NaN
#
#        Expected Years of Schooling (years)  \
# 70                                     NaN
# 75                                     NaN
# 80                                     NaN
# 85                                     NaN
# 90                                     NaN
# ...                                    ...
# 49727                                 10.3
# 49728                                 10.3
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 70                                                   NaN
# 75                                                   NaN
# 80                                                   NaN
# 85                                                   NaN
# 90                                                   NaN
# ...                                                  ...
# 49727                                        2858.616749
# 49728                                        2884.156050
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
#
#        Actual Human Development Index (UNDP)
# 70                                       NaN
# 75                                       NaN
# 80                                       NaN
# 85                                       NaN
# 90                                       NaN
# ...                                      ...
# 49727                                  0.529
# 49728                                  0.532
# 49729                                  0.535
# 49730                                    NaN
# 49731                                    NaN
#
# [19737 rows x 8 columns]

# %%
factors["Weighted Life Expectancy"] = np.nan
factors["Weighted YOS"] = np.nan
factors["Weighted Expected YOS"] = np.nan
factors["Weighted GNI"] = np.nan

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 75     Afghanistan  1875                          4247357.0              NaN
# 80     Afghanistan  1880                          4354370.0              NaN
# 85     Afghanistan  1885                          4464010.0              NaN
# 90     Afghanistan  1890                          4576341.0              NaN
# ...            ...   ...                                ...              ...
# 49727     Zimbabwe  2015                         13814642.0           59.534
# 49728     Zimbabwe  2016                         14030338.0           60.294
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 75                                                  0.01
# 80                                                  0.01
# 85                                                  0.01
# 90                                                  0.01
# ...                                                  ...
# 49727                                               8.20
# 49728                                               8.20
# 49729                                               8.20
# 49730                                                NaN
# 49731                                                NaN
#
#        Expected Years of Schooling (years)  \
# 70                                     NaN
# 75                                     NaN
# 80                                     NaN
# 85                                     NaN
# 90                                     NaN
# ...                                    ...
# 49727                                 10.3
# 49728                                 10.3
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 70                                                   NaN
# 75                                                   NaN
# 80                                                   NaN
# 85                                                   NaN
# 90                                                   NaN
# ...                                                  ...
# 49727                                        2858.616749
# 49728                                        2884.156050
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
#
#        Actual Human Development Index (UNDP)  Weighted Life Expectancy  \
# 70                                       NaN                       NaN
# 75                                       NaN                       NaN
# 80                                       NaN                       NaN
# 85                                       NaN                       NaN
# 90                                       NaN                       NaN
# ...                                      ...                       ...
# 49727                                  0.529                       NaN
# 49728                                  0.532                       NaN
# 49729                                  0.535                       NaN
# 49730                                    NaN                       NaN
# 49731                                    NaN                       NaN
#
#        Weighted YOS  Weighted Expected YOS  Weighted GNI
# 70              NaN                    NaN           NaN
# 75              NaN                    NaN           NaN
# 80              NaN                    NaN           NaN
# 85              NaN                    NaN           NaN
# 90              NaN                    NaN           NaN
# ...             ...                    ...           ...
# 49727           NaN                    NaN           NaN
# 49728           NaN                    NaN           NaN
# 49729           NaN                    NaN           NaN
# 49730           NaN                    NaN           NaN
# 49731           NaN                    NaN           NaN
#
# [19737 rows x 12 columns]

# %%
factors = factors[["Entity",
                   "Year", 
                   "Population (historical estimates)", 
                   "Life expectancy", "Weighted Life Expectancy", 
                   "Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))", "Weighted YOS",
                   "Expected Years of Schooling (years)", "Weighted Expected YOS",
                   "GNI per capita, PPP (constant 2017 international $)", "Weighted GNI",
                   "Actual Human Development Index (UNDP)"
                  ]]

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 75     Afghanistan  1875                          4247357.0              NaN
# 80     Afghanistan  1880                          4354370.0              NaN
# 85     Afghanistan  1885                          4464010.0              NaN
# 90     Afghanistan  1890                          4576341.0              NaN
# ...            ...   ...                                ...              ...
# 49727     Zimbabwe  2015                         13814642.0           59.534
# 49728     Zimbabwe  2016                         14030338.0           60.294
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
#
#        Weighted Life Expectancy  \
# 70                          NaN
# 75                          NaN
# 80                          NaN
# 85                          NaN
# 90                          NaN
# ...                         ...
# 49727                       NaN
# 49728                       NaN
# 49729                       NaN
# 49730                       NaN
# 49731                       NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 75                                                  0.01
# 80                                                  0.01
# 85                                                  0.01
# 90                                                  0.01
# ...                                                  ...
# 49727                                               8.20
# 49728                                               8.20
# 49729                                               8.20
# 49730                                                NaN
# 49731                                                NaN
#
#        Weighted YOS  Expected Years of Schooling (years)  \
# 70              NaN                                  NaN
# 75              NaN                                  NaN
# 80              NaN                                  NaN
# 85              NaN                                  NaN
# 90              NaN                                  NaN
# ...             ...                                  ...
# 49727           NaN                                 10.3
# 49728           NaN                                 10.3
# 49729           NaN                                 10.3
# 49730           NaN                                  NaN
# 49731           NaN                                  NaN
#
#        Weighted Expected YOS  \
# 70                       NaN
# 75                       NaN
# 80                       NaN
# 85                       NaN
# 90                       NaN
# ...                      ...
# 49727                    NaN
# 49728                    NaN
# 49729                    NaN
# 49730                    NaN
# 49731                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  Weighted GNI  \
# 70                                                   NaN             NaN
# 75                                                   NaN             NaN
# 80                                                   NaN             NaN
# 85                                                   NaN             NaN
# 90                                                   NaN             NaN
# ...                                                  ...             ...
# 49727                                        2858.616749             NaN
# 49728                                        2884.156050             NaN
# 49729                                        3207.887558             NaN
# 49730                                        3262.224759             NaN
# 49731                                                NaN             NaN
#
#        Actual Human Development Index (UNDP)
# 70                                       NaN
# 75                                       NaN
# 80                                       NaN
# 85                                       NaN
# 90                                       NaN
# ...                                      ...
# 49727                                  0.529
# 49728                                  0.532
# 49729                                  0.535
# 49730                                    NaN
# 49731                                    NaN
#
# [19737 rows x 12 columns]

# %%
print(factors['Population (historical estimates)'].loc[factors['Year'] == 1870].mean())
# Out:
# 10992194.0990991

# %%
print(factors['Population (historical estimates)'].loc[(factors['Year'] == 1870) 
                                                       & (pd.notna(factors['Life expectancy']))].mean())
# Out:
# 12518941.8

# %%
print(factors['Population (historical estimates)'].loc[(factors['Year'] == 1870) 
                                                       & (pd.notna(factors['Life expectancy']))])
# Out:
# 2464      4528451.0
# 4018      5097637.0
# 11333     1887969.0
# 14644    38184704.0
# 19378       69836.0
# 21448    34388672.0
# 30430     3609009.0
# 32568     1736968.0
# 42380     4168145.0
# 46846    31518027.0
# Name: Population (historical estimates), dtype: float64

# %%
print(factors['Life expectancy'].loc[(factors['Year'] == 1870) 
                                                       & (pd.notna(factors['Life expectancy']))])
# Out:
# 2464     34.400002
# 4018     40.900002
# 11333    45.970001
# 14644    36.389999
# 19378    38.340000
# 21448    36.592640
# 30430    37.320000
# 32568    50.849998
# 42380    44.970001
# 46846    40.605000
# Name: Life expectancy, dtype: float64

# %%
factors['Weighted Life Expectancy'].loc[(factors['Year'] == 1870) & (pd.notna(factors['Life expectancy']))] = (
    factors['Population (historical estimates)'].loc[(factors['Year'] == 1870) & (pd.notna(factors['Life expectancy']))] 
    / factors['Population (historical estimates)'].loc[(factors['Year'] == 1870) 
                                                       & (pd.notna(factors['Life expectancy']))].mean())

# %%
factors.loc[(factors['Year'] == 1870) & (pd.notna(factors['Life expectancy']))]
# Out:
#                   Entity  Year  Population (historical estimates)  \
# 200          Afghanistan  2000                         20779957.0
# 422              Albania  2000                          3129246.0
# 644              Algeria  2000                         31042238.0
# 731       American Samoa  2000                            57816.0
# 953              Andorra  2000                            65390.0
# ...                  ...   ...                                ...
# 48824  Wallis and Futuna  2000                            14697.0
# 49046     Western Sahara  2000                           314116.0
# 49268              Yemen  2000                         17409071.0
# 49490             Zambia  2000                         10415942.0
# 49712           Zimbabwe  2000                         11881482.0
#
#        Life expectancy  Weighted Life Expectancy  \
# 200             55.841                  0.791490
# 422             73.955                  0.119190
# 644             70.640                  1.182372
# 731             71.184                  0.002202
# 953             78.857                  0.002491
# ...                ...                       ...
# 48824           76.653                  0.000560
# 49046           62.615                  0.011964
# 49268           60.683                  0.663096
# 49490           44.000                  0.396734
# 49712           44.649                  0.452555
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 200                                                  2.2
# 422                                                  8.8
# 644                                                  5.9
# 731                                                  NaN
# 953                                                  6.7
# ...                                                  ...
# 48824                                                NaN
# 49046                                                NaN
# 49268                                                1.2
# 49490                                                5.9
# 49712                                                6.5
#
#        Weighted YOS  Expected Years of Schooling (years)  \
# 200             NaN                                  5.9
# 422             NaN                                 10.6
# 644             NaN                                 10.9
# 731             NaN                                  NaN
# 953             NaN                                 10.8
# ...             ...                                  ...
# 48824           NaN                                  NaN
# 49046           NaN                                  NaN
# 49268           NaN                                  7.9
# 49490           NaN                                  9.8
# 49712           NaN                                  9.8
#
#        Weighted Expected YOS  \
# 200                      NaN
# 422                      NaN
# 644                      NaN
# 731                      NaN
# 953                      NaN
# ...                      ...
# 48824                    NaN
# 49046                    NaN
# 49268                    NaN
# 49490                    NaN
# 49712                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  Weighted GNI  \
# 200                                                  NaN             NaN
# 422                                                  NaN             NaN
# 644                                          8391.639382             NaN
# 731                                                  NaN             NaN
# 953                                                  NaN             NaN
# ...                                                  ...             ...
# 48824                                                NaN             NaN
# 49046                                                NaN             NaN
# 49268                                                NaN             NaN
# 49490                                                NaN             NaN
# 49712                                                NaN             NaN
#
#        Actual Human Development Index (UNDP)
# 200                                      NaN
# 422                                    0.669
# 644                                    0.644
# 731                                      NaN
# 953                                    0.759
# ...                                      ...
# 48824                                    NaN
# 49046                                    NaN
# 49268                                  0.443
# 49490                                  0.432
# 49712                                  0.440
#
# [234 rows x 12 columns]

# %%
for year in range(1800, 2022):
    factors['Weighted Life Expectancy'].loc[(factors['Year'] == year) & (pd.notna(factors['Life expectancy']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                         & (pd.notna(factors['Life expectancy']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == f"{year}") 
                                                           & (pd.notna(factors['Life expectancy']))].mean())
    
    
    factors['Weighted YOS'].loc[(factors['Year'] == f"{year}") & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == f"{year}") 
                                                         & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == f"{year}") 
                                                           & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))].mean())
    
    factors['Weighted Expected YOS'].loc[(factors['Year'] == f"{year}") & (pd.notna(factors['Expected Years of Schooling (years)']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == f"{year}") 
                                                         & (pd.notna(factors['Expected Years of Schooling (years)']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == f"{year}") 
                                                           & (pd.notna(factors['Expected Years of Schooling (years)']))].mean())
    
    factors['Weighted GNI'].loc[(factors['Year'] == f"{year}") & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == f"{year}") 
                                                         & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == f"{year}") 
                                                           & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))].mean())

# %%
factors.loc[(factors['Year'] == 2000) & (pd.notna(factors['Life expectancy']))]
# Out:
#                   Entity  Year  Population (historical estimates)  \
# 200          Afghanistan  2000                         20779957.0
# 422              Albania  2000                          3129246.0
# 644              Algeria  2000                         31042238.0
# 731       American Samoa  2000                            57816.0
# 953              Andorra  2000                            65390.0
# ...                  ...   ...                                ...
# 48824  Wallis and Futuna  2000                            14697.0
# 49046     Western Sahara  2000                           314116.0
# 49268              Yemen  2000                         17409071.0
# 49490             Zambia  2000                         10415942.0
# 49712           Zimbabwe  2000                         11881482.0
#
#        Life expectancy  Weighted Life Expectancy  \
# 200             55.841                  0.791490
# 422             73.955                  0.119190
# 644             70.640                  1.182372
# 731             71.184                  0.002202
# 953             78.857                  0.002491
# ...                ...                       ...
# 48824           76.653                  0.000560
# 49046           62.615                  0.011964
# 49268           60.683                  0.663096
# 49490           44.000                  0.396734
# 49712           44.649                  0.452555
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 200                                                  2.2
# 422                                                  8.8
# 644                                                  5.9
# 731                                                  NaN
# 953                                                  6.7
# ...                                                  ...
# 48824                                                NaN
# 49046                                                NaN
# 49268                                                1.2
# 49490                                                5.9
# 49712                                                6.5
#
#        Weighted YOS  Expected Years of Schooling (years)  \
# 200             NaN                                  5.9
# 422             NaN                                 10.6
# 644             NaN                                 10.9
# 731             NaN                                  NaN
# 953             NaN                                 10.8
# ...             ...                                  ...
# 48824           NaN                                  NaN
# 49046           NaN                                  NaN
# 49268           NaN                                  7.9
# 49490           NaN                                  9.8
# 49712           NaN                                  9.8
#
#        Weighted Expected YOS  \
# 200                      NaN
# 422                      NaN
# 644                      NaN
# 731                      NaN
# 953                      NaN
# ...                      ...
# 48824                    NaN
# 49046                    NaN
# 49268                    NaN
# 49490                    NaN
# 49712                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  Weighted GNI  \
# 200                                                  NaN             NaN
# 422                                                  NaN             NaN
# 644                                          8391.639382             NaN
# 731                                                  NaN             NaN
# 953                                                  NaN             NaN
# ...                                                  ...             ...
# 48824                                                NaN             NaN
# 49046                                                NaN             NaN
# 49268                                                NaN             NaN
# 49490                                                NaN             NaN
# 49712                                                NaN             NaN
#
#        Actual Human Development Index (UNDP)
# 200                                      NaN
# 422                                    0.669
# 644                                    0.644
# 731                                      NaN
# 953                                    0.759
# ...                                      ...
# 48824                                    NaN
# 49046                                    NaN
# 49268                                  0.443
# 49490                                  0.432
# 49712                                  0.440
#
# [234 rows x 12 columns]
