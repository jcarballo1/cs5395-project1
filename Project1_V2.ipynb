# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# ignores warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# reads in csv file

df = pd.read_csv("aggregate_hdi_indicators_with_population.csv")

# %%
# display dataframe created from csv file

df
# Out:
#             Entity Code  Year  Population (historical estimates)  \
# 0      Afghanistan  AFG  1800                          3280000.0
# 1      Afghanistan  AFG  1801                          3280000.0
# 2      Afghanistan  AFG  1802                          3280000.0
# 3      Afghanistan  AFG  1803                          3280000.0
# 4      Afghanistan  AFG  1804                          3280000.0
# ...            ...  ...   ...                                ...
# 49729     Zimbabwe  ZWE  2017                         14236599.0
# 49730     Zimbabwe  ZWE  2018                         14438812.0
# 49731     Zimbabwe  ZWE  2019                         14645473.0
# 49732     Zimbabwe  ZWE  2020                         14862927.0
# 49733     Zimbabwe  ZWE  2021                         15092171.0
#
#        Fertility rate (Complete Gapminder, v12) (2017)  \
# 0                                                 7.00
# 1                                                 7.00
# 2                                                 7.00
# 3                                                 7.00
# 4                                                 7.00
# ...                                                ...
# 49729                                             3.68
# 49730                                              NaN
# 49731                                              NaN
# 49732                                              NaN
# 49733                                              NaN
#
#        Mortality rate, infant (per 1,000 live births)  Life expectancy  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# ...                                               ...              ...
# 49729                                            4.05           60.812
# 49730                                            3.93           61.195
# 49731                                            3.84           61.490
# 49732                                             NaN              NaN
# 49733                                             NaN              NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                                8.2
# 49730                                                NaN
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Expected Years of Schooling (years)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
# 49732                                  NaN
# 49733                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Actual Human Development Index (UNDP)
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 49729                                  0.535
# 49730                                    NaN
# 49731                                    NaN
# 49732                                    NaN
# 49733                                    NaN
#
# [49734 rows x 11 columns]

# %%
# calculate HDI rate per year 

#life expectancy index
#<-- ([Life expectancy] - [Life Expectancy Minimum]) / ([Life Expectancy Goalpost] - [Life Expectancy Minimum])
# ([life expentance of country] - 20) / (85 - 20))

#education expectancy index
#((([Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))] 
# - [Mean Years of Schooling Minimum]) / ([Mean Years of Schooling Goalpost] - [Mean Years of Schooling Minimum])) + (([Expected Years of Schooling (years)] - [Expected Years of Schooling Minimum]) 
# / ([Expected Years of Schooling Goalpost] - [Expected Years of Schooling Minimum]))) / 2

#income expectancy index
# (LN([GNI per capita, PPP (constant 2017 international $)]) - LN([GNI per Capita Minimum])) 
# / (LN([GNI per Capita Goalpost]) - LN([GNI per Capita Minimum]))

#HDI
# ([Calculated Life Expectancy Index] * [Calculated Education Index] * [Calculated GNI per Capita Index]) ^ (1/3)


# find life expectancy weight for each country (life expectancy/global life expetancy)
# apply weight to life expectany (weight (^) * life expectancy)
# create new column to store
# use all countries weighted life expectancies to get global life expectancy
# do with other factors
# find gobal HDI

# %%
# drop unnecessary columns & rename dataframe

factors = df.drop(columns = ['Fertility rate (Complete Gapminder, v12) (2017)', 'Mortality rate, infant (per 1,000 live births)', 'Code'])

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 0      Afghanistan  1800                          3280000.0              NaN
# 1      Afghanistan  1801                          3280000.0              NaN
# 2      Afghanistan  1802                          3280000.0              NaN
# 3      Afghanistan  1803                          3280000.0              NaN
# 4      Afghanistan  1804                          3280000.0              NaN
# ...            ...   ...                                ...              ...
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
# 49732     Zimbabwe  2020                         14862927.0              NaN
# 49733     Zimbabwe  2021                         15092171.0              NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                                8.2
# 49730                                                NaN
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Expected Years of Schooling (years)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
# 49732                                  NaN
# 49733                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
# 49732                                                NaN
# 49733                                                NaN
#
#        Actual Human Development Index (UNDP)
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 49729                                  0.535
# 49730                                    NaN
# 49731                                    NaN
# 49732                                    NaN
# 49733                                    NaN
#
# [49734 rows x 8 columns]

# %%
# drop all rows that have less than 4 non-na values

factors = factors.dropna(thresh=4)

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 75     Afghanistan  1875                          4247357.0              NaN
# 80     Afghanistan  1880                          4354370.0              NaN
# 85     Afghanistan  1885                          4464010.0              NaN
# 90     Afghanistan  1890                          4576341.0              NaN
# ...            ...   ...                                ...              ...
# 49727     Zimbabwe  2015                         13814642.0           59.534
# 49728     Zimbabwe  2016                         14030338.0           60.294
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 75                                                  0.01
# 80                                                  0.01
# 85                                                  0.01
# 90                                                  0.01
# ...                                                  ...
# 49727                                               8.20
# 49728                                               8.20
# 49729                                               8.20
# 49730                                                NaN
# 49731                                                NaN
#
#        Expected Years of Schooling (years)  \
# 70                                     NaN
# 75                                     NaN
# 80                                     NaN
# 85                                     NaN
# 90                                     NaN
# ...                                    ...
# 49727                                 10.3
# 49728                                 10.3
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 70                                                   NaN
# 75                                                   NaN
# 80                                                   NaN
# 85                                                   NaN
# 90                                                   NaN
# ...                                                  ...
# 49727                                        2858.616749
# 49728                                        2884.156050
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
#
#        Actual Human Development Index (UNDP)
# 70                                       NaN
# 75                                       NaN
# 80                                       NaN
# 85                                       NaN
# 90                                       NaN
# ...                                      ...
# 49727                                  0.529
# 49728                                  0.532
# 49729                                  0.535
# 49730                                    NaN
# 49731                                    NaN
#
# [19737 rows x 8 columns]

# %%
# create new rows to hold weights

factors["Life Expectancy Weight"] = np.nan
factors["Weighted Life Expectancy"] = np.nan
factors["YOS Weight"] = np.nan
factors["Weighted YOS"] = np.nan
factors["Expected YOS Weight"] = np.nan
factors["Weighted Expected YOS"] = np.nan
factors["GNI Weight"] = np.nan
factors["Weighted GNI"] = np.nan

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 75     Afghanistan  1875                          4247357.0              NaN
# 80     Afghanistan  1880                          4354370.0              NaN
# 85     Afghanistan  1885                          4464010.0              NaN
# 90     Afghanistan  1890                          4576341.0              NaN
# ...            ...   ...                                ...              ...
# 49727     Zimbabwe  2015                         13814642.0           59.534
# 49728     Zimbabwe  2016                         14030338.0           60.294
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 75                                                  0.01
# 80                                                  0.01
# 85                                                  0.01
# 90                                                  0.01
# ...                                                  ...
# 49727                                               8.20
# 49728                                               8.20
# 49729                                               8.20
# 49730                                                NaN
# 49731                                                NaN
#
#        Expected Years of Schooling (years)  \
# 70                                     NaN
# 75                                     NaN
# 80                                     NaN
# 85                                     NaN
# 90                                     NaN
# ...                                    ...
# 49727                                 10.3
# 49728                                 10.3
# 49729                                 10.3
# 49730                                  NaN
# 49731                                  NaN
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 70                                                   NaN
# 75                                                   NaN
# 80                                                   NaN
# 85                                                   NaN
# 90                                                   NaN
# ...                                                  ...
# 49727                                        2858.616749
# 49728                                        2884.156050
# 49729                                        3207.887558
# 49730                                        3262.224759
# 49731                                                NaN
#
#        Actual Human Development Index (UNDP)  Life Expectancy Weight  \
# 70                                       NaN                     NaN
# 75                                       NaN                     NaN
# 80                                       NaN                     NaN
# 85                                       NaN                     NaN
# 90                                       NaN                     NaN
# ...                                      ...                     ...
# 49727                                  0.529                     NaN
# 49728                                  0.532                     NaN
# 49729                                  0.535                     NaN
# 49730                                    NaN                     NaN
# 49731                                    NaN                     NaN
#
#        Weighted Life Expectancy  YOS Weight  Weighted YOS  \
# 70                          NaN         NaN           NaN
# 75                          NaN         NaN           NaN
# 80                          NaN         NaN           NaN
# 85                          NaN         NaN           NaN
# 90                          NaN         NaN           NaN
# ...                         ...         ...           ...
# 49727                       NaN         NaN           NaN
# 49728                       NaN         NaN           NaN
# 49729                       NaN         NaN           NaN
# 49730                       NaN         NaN           NaN
# 49731                       NaN         NaN           NaN
#
#        Expected YOS Weight  Weighted Expected YOS  GNI Weight  Weighted GNI
# 70                     NaN                    NaN         NaN           NaN
# 75                     NaN                    NaN         NaN           NaN
# 80                     NaN                    NaN         NaN           NaN
# 85                     NaN                    NaN         NaN           NaN
# 90                     NaN                    NaN         NaN           NaN
# ...                    ...                    ...         ...           ...
# 49727                  NaN                    NaN         NaN           NaN
# 49728                  NaN                    NaN         NaN           NaN
# 49729                  NaN                    NaN         NaN           NaN
# 49730                  NaN                    NaN         NaN           NaN
# 49731                  NaN                    NaN         NaN           NaN
#
# [19737 rows x 16 columns]

# %%
# reorder rows

factors = factors[["Entity",
                   "Year", 
                   "Population (historical estimates)", 
                   "Life expectancy", "Life Expectancy Weight", "Weighted Life Expectancy", 
                   "Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))", "YOS Weight", "Weighted YOS",
                   "Expected Years of Schooling (years)", "Expected YOS Weight", "Weighted Expected YOS",
                   "GNI per capita, PPP (constant 2017 international $)", "GNI Weight", "Weighted GNI",
                   "Actual Human Development Index (UNDP)"
                  ]]

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 75     Afghanistan  1875                          4247357.0              NaN
# 80     Afghanistan  1880                          4354370.0              NaN
# 85     Afghanistan  1885                          4464010.0              NaN
# 90     Afghanistan  1890                          4576341.0              NaN
# ...            ...   ...                                ...              ...
# 49727     Zimbabwe  2015                         13814642.0           59.534
# 49728     Zimbabwe  2016                         14030338.0           60.294
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
#
#        Life Expectancy Weight  Weighted Life Expectancy  \
# 70                        NaN                       NaN
# 75                        NaN                       NaN
# 80                        NaN                       NaN
# 85                        NaN                       NaN
# 90                        NaN                       NaN
# ...                       ...                       ...
# 49727                     NaN                       NaN
# 49728                     NaN                       NaN
# 49729                     NaN                       NaN
# 49730                     NaN                       NaN
# 49731                     NaN                       NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 75                                                  0.01
# 80                                                  0.01
# 85                                                  0.01
# 90                                                  0.01
# ...                                                  ...
# 49727                                               8.20
# 49728                                               8.20
# 49729                                               8.20
# 49730                                                NaN
# 49731                                                NaN
#
#        YOS Weight  Weighted YOS  Expected Years of Schooling (years)  \
# 70            NaN           NaN                                  NaN
# 75            NaN           NaN                                  NaN
# 80            NaN           NaN                                  NaN
# 85            NaN           NaN                                  NaN
# 90            NaN           NaN                                  NaN
# ...           ...           ...                                  ...
# 49727         NaN           NaN                                 10.3
# 49728         NaN           NaN                                 10.3
# 49729         NaN           NaN                                 10.3
# 49730         NaN           NaN                                  NaN
# 49731         NaN           NaN                                  NaN
#
#        Expected YOS Weight  Weighted Expected YOS  \
# 70                     NaN                    NaN
# 75                     NaN                    NaN
# 80                     NaN                    NaN
# 85                     NaN                    NaN
# 90                     NaN                    NaN
# ...                    ...                    ...
# 49727                  NaN                    NaN
# 49728                  NaN                    NaN
# 49729                  NaN                    NaN
# 49730                  NaN                    NaN
# 49731                  NaN                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  GNI Weight  \
# 70                                                   NaN           NaN
# 75                                                   NaN           NaN
# 80                                                   NaN           NaN
# 85                                                   NaN           NaN
# 90                                                   NaN           NaN
# ...                                                  ...           ...
# 49727                                        2858.616749           NaN
# 49728                                        2884.156050           NaN
# 49729                                        3207.887558           NaN
# 49730                                        3262.224759           NaN
# 49731                                                NaN           NaN
#
#        Weighted GNI  Actual Human Development Index (UNDP)
# 70              NaN                                    NaN
# 75              NaN                                    NaN
# 80              NaN                                    NaN
# 85              NaN                                    NaN
# 90              NaN                                    NaN
# ...             ...                                    ...
# 49727           NaN                                  0.529
# 49728           NaN                                  0.532
# 49729           NaN                                  0.535
# 49730           NaN                                    NaN
# 49731           NaN                                    NaN
#
# [19737 rows x 16 columns]

# %%
# test out to find mean of population for only rows where year = 1870

print(factors['Population (historical estimates)'].loc[factors['Year'] == 1870].mean())
# Out:
# 10992194.0990991

# %%
# test out to find mean of population for only rows where year = 1870 and the life expectancy column is not 

print(factors['Population (historical estimates)'].loc[(factors['Year'] == 1870) 
                                                       & (pd.notna(factors['Life expectancy']))].mean())
# Out:
# 12518941.8

# %%
# test out weight equation on the above requirements

factors['Life Expectancy Weight'].loc[(factors['Year'] == 1870) & (pd.notna(factors['Life expectancy']))] = (
    factors['Population (historical estimates)'].loc[(factors['Year'] == 1870) & (pd.notna(factors['Life expectancy']))] 
    / factors['Population (historical estimates)'].loc[(factors['Year'] == 1870) 
                                                       & (pd.notna(factors['Life expectancy']))].mean())

# %%
# take a look at dataframe to see how its been populated based on equation above

factors.loc[(factors['Year'] == 1870) & (pd.notna(factors['Life expectancy']))]
# Out:
#                Entity  Year  Population (historical estimates)  \
# 2464          Austria  1870                          4528451.0
# 4018          Belgium  1870                          5097637.0
# 11333         Denmark  1870                          1887969.0
# 14644          France  1870                         38184704.0
# 19378         Iceland  1870                            69836.0
# 21448           Japan  1870                         34388672.0
# 30430     Netherlands  1870                          3609009.0
# 32568          Norway  1870                          1736968.0
# 42380          Sweden  1870                          4168145.0
# 46846  United Kingdom  1870                         31518027.0
#
#        Life expectancy  Life Expectancy Weight  Weighted Life Expectancy  \
# 2464         34.400002                0.361728                       NaN
# 4018         40.900002                0.407194                       NaN
# 11333        45.970001                0.150809                       NaN
# 14644        36.389999                3.050154                       NaN
# 19378        38.340000                0.005578                       NaN
# 21448        36.592640                2.746931                       NaN
# 30430        37.320000                0.288284                       NaN
# 32568        50.849998                0.138747                       NaN
# 42380        44.970001                0.332947                       NaN
# 46846        40.605000                2.517627                       NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 2464                                                2.13
# 4018                                                2.27
# 11333                                               2.39
# 14644                                               0.66
# 19378                                               0.74
# 21448                                               0.42
# 30430                                               2.89
# 32568                                               3.82
# 42380                                               3.51
# 46846                                               0.80
#
#        YOS Weight  Weighted YOS  Expected Years of Schooling (years)  \
# 2464          NaN           NaN                                  NaN
# 4018          NaN           NaN                                  NaN
# 11333         NaN           NaN                                  NaN
# 14644         NaN           NaN                                  NaN
# 19378         NaN           NaN                                  NaN
# 21448         NaN           NaN                                  NaN
# 30430         NaN           NaN                                  NaN
# 32568         NaN           NaN                                  NaN
# 42380         NaN           NaN                                  NaN
# 46846         NaN           NaN                                  NaN
#
#        Expected YOS Weight  Weighted Expected YOS  \
# 2464                   NaN                    NaN
# 4018                   NaN                    NaN
# 11333                  NaN                    NaN
# 14644                  NaN                    NaN
# 19378                  NaN                    NaN
# 21448                  NaN                    NaN
# 30430                  NaN                    NaN
# 32568                  NaN                    NaN
# 42380                  NaN                    NaN
# 46846                  NaN                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  GNI Weight  \
# 2464                                                 NaN           NaN
# 4018                                                 NaN           NaN
# 11333                                                NaN           NaN
# 14644                                                NaN           NaN
# 19378                                                NaN           NaN
# 21448                                                NaN           NaN
# 30430                                                NaN           NaN
# 32568                                                NaN           NaN
# 42380                                                NaN           NaN
# 46846                                                NaN           NaN
#
#        Weighted GNI  Actual Human Development Index (UNDP)
# 2464            NaN                                    NaN
# 4018            NaN                                    NaN
# 11333           NaN                                    NaN
# 14644           NaN                                    NaN
# 19378           NaN                                    NaN
# 21448           NaN                                    NaN
# 30430           NaN                                    NaN
# 32568           NaN                                    NaN
# 42380           NaN                                    NaN
# 46846           NaN                                    NaN

# %%
factors.loc[factors['Year'] == 1870]
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 292        Albania  1870                           606465.0              NaN
# 514        Algeria  1870                          3461795.0              NaN
# 1576     Argentina  1870                          1793839.0              NaN
# 2242     Australia  1870                          1759825.0              NaN
# ...            ...   ...                                ...              ...
# 47512      Uruguay  1870                           342659.0              NaN
# 48400    Venezuela  1870                          1700687.0              NaN
# 49138        Yemen  1870                          2813705.0              NaN
# 49360       Zambia  1870                          1597641.0              NaN
# 49582     Zimbabwe  1870                           812080.0              NaN
#
#        Life Expectancy Weight  Weighted Life Expectancy  \
# 70                        NaN                       NaN
# 292                       NaN                       NaN
# 514                       NaN                       NaN
# 1576                      NaN                       NaN
# 2242                      NaN                       NaN
# ...                       ...                       ...
# 47512                     NaN                       NaN
# 48400                     NaN                       NaN
# 49138                     NaN                       NaN
# 49360                     NaN                       NaN
# 49582                     NaN                       NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 292                                                 0.02
# 514                                                 0.08
# 1576                                                0.28
# 2242                                                1.61
# ...                                                  ...
# 47512                                               0.24
# 48400                                               0.01
# 49138                                               0.01
# 49360                                               0.01
# 49582                                               0.01
#
#        YOS Weight  Weighted YOS  Expected Years of Schooling (years)  \
# 70            NaN           NaN                                  NaN
# 292           NaN           NaN                                  NaN
# 514           NaN           NaN                                  NaN
# 1576          NaN           NaN                                  NaN
# 2242          NaN           NaN                                  NaN
# ...           ...           ...                                  ...
# 47512         NaN           NaN                                  NaN
# 48400         NaN           NaN                                  NaN
# 49138         NaN           NaN                                  NaN
# 49360         NaN           NaN                                  NaN
# 49582         NaN           NaN                                  NaN
#
#        Expected YOS Weight  Weighted Expected YOS  \
# 70                     NaN                    NaN
# 292                    NaN                    NaN
# 514                    NaN                    NaN
# 1576                   NaN                    NaN
# 2242                   NaN                    NaN
# ...                    ...                    ...
# 47512                  NaN                    NaN
# 48400                  NaN                    NaN
# 49138                  NaN                    NaN
# 49360                  NaN                    NaN
# 49582                  NaN                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  GNI Weight  \
# 70                                                   NaN           NaN
# 292                                                  NaN           NaN
# 514                                                  NaN           NaN
# 1576                                                 NaN           NaN
# 2242                                                 NaN           NaN
# ...                                                  ...           ...
# 47512                                                NaN           NaN
# 48400                                                NaN           NaN
# 49138                                                NaN           NaN
# 49360                                                NaN           NaN
# 49582                                                NaN           NaN
#
#        Weighted GNI  Actual Human Development Index (UNDP)
# 70              NaN                                    NaN
# 292             NaN                                    NaN
# 514             NaN                                    NaN
# 1576            NaN                                    NaN
# 2242            NaN                                    NaN
# ...             ...                                    ...
# 47512           NaN                                    NaN
# 48400           NaN                                    NaN
# 49138           NaN                                    NaN
# 49360           NaN                                    NaN
# 49582           NaN                                    NaN
#
# [111 rows x 16 columns]

# %%
# go through all rows of dataframe and find weights for all factors based on year and that factor column is not nan

for year in range(1800, 2020):
    factors['Life Expectancy Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['Life expectancy']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                         & (pd.notna(factors['Life expectancy']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                           & (pd.notna(factors['Life expectancy']))].mean())
    
    
    factors['YOS Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                         & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                           & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))].mean())
    
    factors['Expected YOS Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['Expected Years of Schooling (years)']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                         & (pd.notna(factors['Expected Years of Schooling (years)']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                           & (pd.notna(factors['Expected Years of Schooling (years)']))].mean())
    
    factors['GNI Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))] = (
        factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                         & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))] 
        / factors['Population (historical estimates)'].loc[(factors['Year'] == year) 
                                                           & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))].mean())

# %%
# take a look at dataframe
factors.loc[(factors['Year'] == 1900) & (pd.notna(factors['Life expectancy']))]
# Out:
#                Entity  Year  Population (historical estimates)  \
# 1606        Argentina  1900                          4689224.0
# 3826          Belarus  1900                          4909551.0
# 4048          Belgium  1900                          6717693.0
# 5008          Bolivia  1900                          1809836.0
# 5746           Brazil  1900                         18063384.0
# 6262         Bulgaria  1900                          3994654.0
# 8554            Chile  1900                          3135464.0
# 8998         Colombia  1900                          4089052.0
# 9736       Costa Rica  1900                           316531.0
# 10402            Cuba  1900                          1718198.0
# 10918         Czechia  1900                          9334000.0
# 11363         Denmark  1900                          2565597.0
# 13361         Estonia  1900                           872770.0
# 14452         Finland  1900                          2641828.0
# 14674          France  1900                         40013112.0
# 17632       Guatemala  1900                          1357590.0
# 19186         Hungary  1900                          7106099.0
# 19408         Iceland  1900                            77857.0
# 21034           Italy  1900                         33442744.0
# 21256         Jamaica  1900                           725908.0
# 21478           Japan  1900                         43805856.0
# 21922      Kazakhstan  1900                          4183928.0
# 24601       Lithuania  1900                          2525068.0
# 27709          Mexico  1900                         13383654.0
# 30460     Netherlands  1900                          5120625.0
# 32598          Norway  1900                          2224417.0
# 34152        Paraguay  1900                           456307.0
# 36158          Russia  1900                         64946671.0
# 41265           Spain  1900                         18592431.0
# 42410          Sweden  1900                          5120942.0
# 42632     Switzerland  1900                          3284773.0
# 46121         Ukraine  1900                         23477813.0
# 46876  United Kingdom  1900                         41433090.0
# 47542         Uruguay  1900                           921056.0
# 48430       Venezuela  1900                          2697074.0
#
#        Life expectancy  Life Expectancy Weight  Weighted Life Expectancy  \
# 1606         39.000000                0.432181                       NaN
# 3826         36.200001                0.452487                       NaN
# 4048         46.520000                0.619134                       NaN
# 5008         26.000000                0.166803                       NaN
# 5746         29.000000                1.664807                       NaN
# 6262         40.200001                0.368166                       NaN
# 8554         29.000000                0.288979                       NaN
# 8998         29.000000                0.376866                       NaN
# 9736         32.000000                0.029173                       NaN
# 10402        32.000000                0.158357                       NaN
# 10918        40.266159                0.860266                       NaN
# 11363        51.869999                0.236458                       NaN
# 13361        43.099998                0.080439                       NaN
# 14452        41.740002                0.243483                       NaN
# 14674        45.009998                3.687798                       NaN
# 17632        24.000000                0.125122                       NaN
# 19186        37.335918                0.654932                       NaN
# 19408        46.650002                0.007176                       NaN
# 21034        41.669998                3.082242                       NaN
# 21256        37.799999                0.066903                       NaN
# 21478        38.599998                4.037355                       NaN
# 21922        28.100000                0.385611                       NaN
# 24601        41.700001                0.232722                       NaN
# 27709        25.000000                1.233501                       NaN
# 30460        48.380001                0.471941                       NaN
# 32598        53.470001                0.205013                       NaN
# 34152        25.000000                0.042055                       NaN
# 36158        30.500000                5.985793                       NaN
# 41265        34.799999                1.713566                       NaN
# 42410        52.209999                0.471970                       NaN
# 42632        47.480000                0.302740                       NaN
# 46121        36.599998                2.163826                       NaN
# 46876        45.619999                3.818670                       NaN
# 47542        49.000000                0.084889                       NaN
# 48430        28.000000                0.248575                       NaN
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 1606                                                0.78
# 3826                                                 NaN
# 4048                                                2.58
# 5008                                                0.17
# 5746                                                0.47
# 6262                                                1.33
# 8554                                                1.30
# 8998                                                0.74
# 9736                                                1.21
# 10402                                               0.38
# 10918                                               3.65
# 11363                                               2.76
# 13361                                                NaN
# 14452                                               0.80
# 14674                                               1.97
# 17632                                               0.64
# 19186                                               3.03
# 19408                                               1.29
# 21034                                               1.47
# 21256                                               1.52
# 21478                                               1.29
# 21922                                                NaN
# 24601                                                NaN
# 27709                                               0.76
# 30460                                               3.35
# 32598                                               5.31
# 34152                                               0.55
# 36158                                               0.30
# 41265                                               3.07
# 42410                                               4.21
# 42632                                               5.10
# 46121                                                NaN
# 46876                                               1.96
# 47542                                               0.80
# 48430                                               0.32
#
#        YOS Weight  Weighted YOS  Expected Years of Schooling (years)  \
# 1606     0.347993           NaN                                  NaN
# 3826          NaN           NaN                                  NaN
# 4048     0.498528           NaN                                  NaN
# 5008     0.134310           NaN                                  NaN
# 5746     1.340505           NaN                                  NaN
# 6262     0.296448           NaN                                  NaN
# 8554     0.232686           NaN                                  NaN
# 8998     0.303453           NaN                                  NaN
# 9736     0.023490           NaN                                  NaN
# 10402    0.127509           NaN                                  NaN
# 10918    0.692687           NaN                                  NaN
# 11363    0.190396           NaN                                  NaN
# 13361         NaN           NaN                                  NaN
# 14452    0.196053           NaN                                  NaN
# 14674    2.969420           NaN                                  NaN
# 17632    0.100748           NaN                                  NaN
# 19186    0.527352           NaN                                  NaN
# 19408    0.005778           NaN                                  NaN
# 21034    2.481825           NaN                                  NaN
# 21256    0.053870           NaN                                  NaN
# 21478    3.250884           NaN                                  NaN
# 21922         NaN           NaN                                  NaN
# 24601         NaN           NaN                                  NaN
# 27709    0.993217           NaN                                  NaN
# 30460    0.380008           NaN                                  NaN
# 32598    0.165077           NaN                                  NaN
# 34152    0.033863           NaN                                  NaN
# 36158    4.819768           NaN                                  NaN
# 41265    1.379766           NaN                                  NaN
# 42410    0.380031           NaN                                  NaN
# 42632    0.243767           NaN                                  NaN
# 46121         NaN           NaN                                  NaN
# 46876    3.074798           NaN                                  NaN
# 47542    0.068353           NaN                                  NaN
# 48430    0.200153           NaN                                  NaN
#
#        Expected YOS Weight  Weighted Expected YOS  \
# 1606                   NaN                    NaN
# 3826                   NaN                    NaN
# 4048                   NaN                    NaN
# 5008                   NaN                    NaN
# 5746                   NaN                    NaN
# 6262                   NaN                    NaN
# 8554                   NaN                    NaN
# 8998                   NaN                    NaN
# 9736                   NaN                    NaN
# 10402                  NaN                    NaN
# 10918                  NaN                    NaN
# 11363                  NaN                    NaN
# 13361                  NaN                    NaN
# 14452                  NaN                    NaN
# 14674                  NaN                    NaN
# 17632                  NaN                    NaN
# 19186                  NaN                    NaN
# 19408                  NaN                    NaN
# 21034                  NaN                    NaN
# 21256                  NaN                    NaN
# 21478                  NaN                    NaN
# 21922                  NaN                    NaN
# 24601                  NaN                    NaN
# 27709                  NaN                    NaN
# 30460                  NaN                    NaN
# 32598                  NaN                    NaN
# 34152                  NaN                    NaN
# 36158                  NaN                    NaN
# 41265                  NaN                    NaN
# 42410                  NaN                    NaN
# 42632                  NaN                    NaN
# 46121                  NaN                    NaN
# 46876                  NaN                    NaN
# 47542                  NaN                    NaN
# 48430                  NaN                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  GNI Weight  \
# 1606                                                 NaN           NaN
# 3826                                                 NaN           NaN
# 4048                                                 NaN           NaN
# 5008                                                 NaN           NaN
# 5746                                                 NaN           NaN
# 6262                                                 NaN           NaN
# 8554                                                 NaN           NaN
# 8998                                                 NaN           NaN
# 9736                                                 NaN           NaN
# 10402                                                NaN           NaN
# 10918                                                NaN           NaN
# 11363                                                NaN           NaN
# 13361                                                NaN           NaN
# 14452                                                NaN           NaN
# 14674                                                NaN           NaN
# 17632                                                NaN           NaN
# 19186                                                NaN           NaN
# 19408                                                NaN           NaN
# 21034                                                NaN           NaN
# 21256                                                NaN           NaN
# 21478                                                NaN           NaN
# 21922                                                NaN           NaN
# 24601                                                NaN           NaN
# 27709                                                NaN           NaN
# 30460                                                NaN           NaN
# 32598                                                NaN           NaN
# 34152                                                NaN           NaN
# 36158                                                NaN           NaN
# 41265                                                NaN           NaN
# 42410                                                NaN           NaN
# 42632                                                NaN           NaN
# 46121                                                NaN           NaN
# 46876                                                NaN           NaN
# 47542                                                NaN           NaN
# 48430                                                NaN           NaN
#
#        Weighted GNI  Actual Human Development Index (UNDP)
# 1606            NaN                                    NaN
# 3826            NaN                                    NaN
# 4048            NaN                                    NaN
# 5008            NaN                                    NaN
# 5746            NaN                                    NaN
# 6262            NaN                                    NaN
# 8554            NaN                                    NaN
# 8998            NaN                                    NaN
# 9736            NaN                                    NaN
# 10402           NaN                                    NaN
# 10918           NaN                                    NaN
# 11363           NaN                                    NaN
# 13361           NaN                                    NaN
# 14452           NaN                                    NaN
# 14674           NaN                                    NaN
# 17632           NaN                                    NaN
# 19186           NaN                                    NaN
# 19408           NaN                                    NaN
# 21034           NaN                                    NaN
# 21256           NaN                                    NaN
# 21478           NaN                                    NaN
# 21922           NaN                                    NaN
# 24601           NaN                                    NaN
# 27709           NaN                                    NaN
# 30460           NaN                                    NaN
# 32598           NaN                                    NaN
# 34152           NaN                                    NaN
# 36158           NaN                                    NaN
# 41265           NaN                                    NaN
# 42410           NaN                                    NaN
# 42632           NaN                                    NaN
# 46121           NaN                                    NaN
# 46876           NaN                                    NaN
# 47542           NaN                                    NaN
# 48430           NaN                                    NaN

# %%
# go through dataframe
# make each factors weighted by multiplying weight by original factors

for year in range(1800, 2020):
    factors['Weighted Life Expectancy'].loc[(factors['Year'] == year) & (pd.notna(factors['Life expectancy']))] = (
        factors['Life expectancy'].loc[(factors['Year'] == year) & (pd.notna(factors['Life expectancy']))]
        * factors['Life Expectancy Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['Life expectancy']))])
    
    
    factors['Weighted YOS'].loc[(factors['Year'] == year) & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))] = (
        factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))'].loc[(factors['Year'] == year) & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))] 
        * factors['YOS Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))']))])
    
    
    factors['Weighted Expected YOS'].loc[(factors['Year'] == year) & (pd.notna(factors['Expected Years of Schooling (years)']))] = (
        factors['Expected Years of Schooling (years)'].loc[(factors['Year'] == year) & (pd.notna(factors['Expected Years of Schooling (years)']))] 
        * factors['Expected YOS Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['Expected Years of Schooling (years)']))])
    
    factors['Weighted GNI'].loc[(factors['Year'] == year) & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))] = (
        factors['GNI per capita, PPP (constant 2017 international $)'].loc[(factors['Year'] == year) & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))] 
        * factors['GNI Weight'].loc[(factors['Year'] == year) & (pd.notna(factors['GNI per capita, PPP (constant 2017 international $)']))])

# %%
factors
# Out:
#             Entity  Year  Population (historical estimates)  Life expectancy  \
# 70     Afghanistan  1870                          4142928.0              NaN
# 75     Afghanistan  1875                          4247357.0              NaN
# 80     Afghanistan  1880                          4354370.0              NaN
# 85     Afghanistan  1885                          4464010.0              NaN
# 90     Afghanistan  1890                          4576341.0              NaN
# ...            ...   ...                                ...              ...
# 49727     Zimbabwe  2015                         13814642.0           59.534
# 49728     Zimbabwe  2016                         14030338.0           60.294
# 49729     Zimbabwe  2017                         14236599.0           60.812
# 49730     Zimbabwe  2018                         14438812.0           61.195
# 49731     Zimbabwe  2019                         14645473.0           61.490
#
#        Life Expectancy Weight  Weighted Life Expectancy  \
# 70                        NaN                       NaN
# 75                        NaN                       NaN
# 80                        NaN                       NaN
# 85                        NaN                       NaN
# 90                        NaN                       NaN
# ...                       ...                       ...
# 49727                0.438038                 26.078146
# 49728                0.439857                 26.520747
# 49729                0.441366                 26.840351
# 49730                0.442753                 27.094253
# 49731                0.444294                 27.319617
#
#        Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))  \
# 70                                                  0.01
# 75                                                  0.01
# 80                                                  0.01
# 85                                                  0.01
# 90                                                  0.01
# ...                                                  ...
# 49727                                               8.20
# 49728                                               8.20
# 49729                                               8.20
# 49730                                                NaN
# 49731                                                NaN
#
#        YOS Weight  Weighted YOS  Expected Years of Schooling (years)  \
# 70       0.376897      0.003769                                  NaN
# 75       0.372985      0.003730                                  NaN
# 80       0.374563      0.003746                                  NaN
# 85       0.366628      0.003666                                  NaN
# 90       0.364788      0.003648                                  NaN
# ...           ...           ...                                  ...
# 49727    0.357247      2.929428                                 10.3
# 49728    0.358717      2.941481                                 10.3
# 49729    0.359934      2.951458                                 10.3
# 49730         NaN           NaN                                  NaN
# 49731         NaN           NaN                                  NaN
#
#        Expected YOS Weight  Weighted Expected YOS  \
# 70                     NaN                    NaN
# 75                     NaN                    NaN
# 80                     NaN                    NaN
# 85                     NaN                    NaN
# 90                     NaN                    NaN
# ...                    ...                    ...
# 49727             0.357910               3.686475
# 49728             0.359391               3.701726
# 49729             0.362513               3.733883
# 49730                  NaN                    NaN
# 49731                  NaN                    NaN
#
#        GNI per capita, PPP (constant 2017 international $)  GNI Weight  \
# 70                                                   NaN           NaN
# 75                                                   NaN           NaN
# 80                                                   NaN           NaN
# 85                                                   NaN           NaN
# 90                                                   NaN           NaN
# ...                                                  ...           ...
# 49727                                        2858.616749      0.301888
# 49728                                        2884.156050      0.303136
# 49729                                        3207.887558      0.369665
# 49730                                        3262.224759      0.299518
# 49731                                                NaN           NaN
#
#        Weighted GNI  Actual Human Development Index (UNDP)
# 70              NaN                                    NaN
# 75              NaN                                    NaN
# 80              NaN                                    NaN
# 85              NaN                                    NaN
# 90              NaN                                    NaN
# ...             ...                                    ...
# 49727    862.981207                                  0.529
# 49728    874.291194                                  0.532
# 49729   1185.842215                                  0.535
# 49730    977.094727                                    NaN
# 49731           NaN                                    NaN
#
# [19737 rows x 16 columns]

# %%
# create new dataframe to contain world values
# take mean of weighted averages for every country by year and store in dataset

column_names = ['Year', 'Population', 'Life Expectancy', 'YOS', 'Expected YOS', 'GNI']
world_values = pd.DataFrame(columns = column_names)

for year in range(1800, 2020):
    population = factors['Population (historical estimates)'].loc[factors['Year'] == year].mean(skipna = True)
    life_expectancy = factors['Weighted Life Expectancy'].loc[factors['Year'] == year].mean(skipna = True)
    yos = factors['Weighted YOS'].loc[factors['Year'] == year].mean(skipna = True)
    expected_yos = factors['Weighted Expected YOS'].loc[factors['Year'] == year].mean(skipna = True)
    gni = factors['Weighted GNI'].loc[factors['Year'] == year].mean(skipna = True)
    # print( "Year: ", year, " Life exp: ", life_expectancy, " YOS: ", yos, " Expected YOS: ", expected_yos, " Weighted GNI: ", weighted_GNI)
    
    world_values = world_values.append({'Year' : year, 'Population' : population, 'Life Expectancy' : life_expectancy, 'YOS': yos, 
                                       'Expected YOS' : expected_yos, 'GNI': gni}, 
                ignore_index = True)

# %%
world_values
# Out:
#        Year    Population  Life Expectancy       YOS  Expected YOS  \
# 0    1800.0  2.500000e+06        32.130001       NaN           NaN
# 1    1801.0  2.489400e+06        36.849998       NaN           NaN
# 2    1802.0  2.478845e+06        40.130001       NaN           NaN
# 3    1803.0  6.785333e+06        40.050921       NaN           NaN
# 4    1804.0  2.457869e+06        39.650002       NaN           NaN
# ..      ...           ...              ...       ...           ...
# 215  2015.0  3.153755e+07        71.999304  7.906675     13.108429
# 216  2016.0  3.189749e+07        72.223146  7.982917     13.188746
# 217  2017.0  3.225577e+07        72.426848  7.998527     13.193718
# 218  2018.0  3.261146e+07        72.612756       NaN           NaN
# 219  2019.0  3.296350e+07        72.783500       NaN           NaN
#
#               GNI
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 215  15471.989544
# 216  15780.970942
# 217  16215.177712
# 218  16586.907293
# 219  16421.030285
#
# [220 rows x 6 columns]

# %%
# make year column integers

world_values['Year'] = world_values['Year'].astype(int)

# %%
world_values
# Out:
#      Year    Population  Life Expectancy       YOS  Expected YOS           GNI
# 0    1800  2.500000e+06        32.130001       NaN           NaN           NaN
# 1    1801  2.489400e+06        36.849998       NaN           NaN           NaN
# 2    1802  2.478845e+06        40.130001       NaN           NaN           NaN
# 3    1803  6.785333e+06        40.050921       NaN           NaN           NaN
# 4    1804  2.457869e+06        39.650002       NaN           NaN           NaN
# ..    ...           ...              ...       ...           ...           ...
# 215  2015  3.153755e+07        71.999304  7.906675     13.108429  15471.989544
# 216  2016  3.189749e+07        72.223146  7.982917     13.188746  15780.970942
# 217  2017  3.225577e+07        72.426848  7.998527     13.193718  16215.177712
# 218  2018  3.261146e+07        72.612756       NaN           NaN  16586.907293
# 219  2019  3.296350e+07        72.783500       NaN           NaN  16421.030285
#
# [220 rows x 6 columns]

# %%
world_values = world_values.dropna()

# %%
world_values
# Out:
#      Year    Population  Life Expectancy       YOS  Expected YOS           GNI
# 190  1990  2.276592e+07        65.459139  5.464198      9.618479  13036.525162
# 191  1991  2.313796e+07        65.638388  5.465263      9.663838  12931.612690
# 192  1992  2.349963e+07        65.816729  5.598505      9.758527  12848.391243
# 193  1993  2.385296e+07        66.000292  5.720805      9.826136  12741.379541
# 194  1994  2.420147e+07        66.191698  5.858699      9.909724  12396.355089
# 195  1995  2.454789e+07        66.393972  5.995026     10.035383   9983.662735
# 196  1996  2.489267e+07        66.607294  6.127245     10.129123  10205.383220
# 197  1997  2.523521e+07        66.831118  6.273268     10.192042  10581.034473
# 198  1998  2.557601e+07        67.063629  6.404265     10.310817  10743.334413
# 199  1999  2.591552e+07        67.305912  6.523771     10.432506  10980.900990
# 200  2000  2.625422e+07        67.557895  6.618851     10.520274  11454.757217
# 201  2001  2.659239e+07        67.820275  6.682958     10.642352  11587.198463
# 202  2002  2.693062e+07        68.092956  6.785627     10.810884  11738.954156
# 203  2003  2.726999e+07        68.375304  6.851142     11.030991  12039.117246
# 204  2004  2.761176e+07        68.666760  6.933564     11.213897  12562.720364
# 205  2005  2.795683e+07        68.968570  7.020443     11.418075  12920.285903
# 206  2006  2.830559e+07        69.280813  7.106697     11.610374  13443.617941
# 207  2007  2.865785e+07        69.602196  7.169292     11.861340  13939.818182
# 208  2008  2.901316e+07        69.928922  7.256572     12.055631  14085.046718
# 209  2009  2.937076e+07        70.256441  7.353739     12.172857  13775.112118
# 210  2010  2.972998e+07        70.579931  7.445982     12.358193  13983.050873
# 211  2011  3.009053e+07        70.894898  7.538435     12.574263  14205.816270
# 212  2012  3.045222e+07        71.197261  7.634480     12.735814  14485.734647
# 213  2013  3.081441e+07        71.483904  7.710409     12.871031  14782.073358
# 214  2014  3.117642e+07        71.752436  7.813513     13.030036  15140.273402
# 215  2015  3.153755e+07        71.999304  7.906675     13.108429  15471.989544
# 216  2016  3.189749e+07        72.223146  7.982917     13.188746  15780.970942
# 217  2017  3.225577e+07        72.426848  7.998527     13.193718  16215.177712

# %%
# create HDI dataframe to contain all calculated indexes and HDI for each year

HDI = column_names = ['Year', 'Population', 'Life Expectancy Index', 'Education Expectancy Index', 'Income Expectancy Index', 'HDI']
HDI = pd.DataFrame(columns = column_names)

for item, rows in world_values.iterrows():
    lei = (world_values['Life Expectancy'].loc[item] - 20)/(85 - 20)
    eei = ((world_values['YOS'].loc[item] / 15) + (world_values['Expected YOS'].loc[item] /18 )) / 2
    iei = (math.log(gni) - math.log(100))/(math.log(75000) - math.log(100))
    hdi = math.pow((lei * eei * iei), (1/3))
    
    # print( "Year: ", year, " Life exp: ", life_expectancy, " YOS: ", yos, " Expected YOS: ", expected_yos, " Weighted GNI: ", weighted_GNI)
    
    HDI = HDI.append({'Year' : rows['Year'],
                      'Population' : rows['Population'],
                      'Life Expectancy Index' : lei, 
                      'Education Expectancy Index' : eei,
                      'Income Expectancy Index': iei,
                      'HDI' : hdi},
                     ignore_index = True)

# %%
HDI
# Out:
#       Year    Population  Life Expectancy Index  Education Expectancy Index  \
# 0   1990.0  2.276592e+07               0.699371                    0.449320
# 1   1991.0  2.313796e+07               0.702129                    0.450615
# 2   1992.0  2.349963e+07               0.704873                    0.457687
# 3   1993.0  2.385296e+07               0.707697                    0.463642
# 4   1994.0  2.420147e+07               0.710642                    0.470560
# 5   1995.0  2.454789e+07               0.713753                    0.478595
# 6   1996.0  2.489267e+07               0.717035                    0.485606
# 7   1997.0  2.523521e+07               0.720479                    0.492221
# 8   1998.0  2.557601e+07               0.724056                    0.499887
# 9   1999.0  2.591552e+07               0.727783                    0.507251
# 10  2000.0  2.625422e+07               0.731660                    0.512858
# 11  2001.0  2.659239e+07               0.735697                    0.518386
# 12  2002.0  2.693062e+07               0.739892                    0.526490
# 13  2003.0  2.726999e+07               0.744235                    0.534788
# 14  2004.0  2.761176e+07               0.748719                    0.542616
# 15  2005.0  2.795683e+07               0.753363                    0.551184
# 16  2006.0  2.830559e+07               0.758166                    0.559400
# 17  2007.0  2.865785e+07               0.763111                    0.568458
# 18  2008.0  2.901316e+07               0.768137                    0.576764
# 19  2009.0  2.937076e+07               0.773176                    0.583260
# 20  2010.0  2.972998e+07               0.778153                    0.591483
# 21  2011.0  3.009053e+07               0.782998                    0.600566
# 22  2012.0  3.045222e+07               0.787650                    0.608255
# 23  2013.0  3.081441e+07               0.792060                    0.614542
# 24  2014.0  3.117642e+07               0.796191                    0.622396
# 25  2015.0  3.153755e+07               0.799989                    0.627679
# 26  2016.0  3.189749e+07               0.803433                    0.632451
# 27  2017.0  3.225577e+07               0.806567                    0.633110
#
#     Income Expectancy Index       HDI
# 0                  0.770558  0.623289
# 1                  0.770558  0.624706
# 2                  0.770558  0.628774
# 3                  0.770558  0.632332
# 4                  0.770558  0.636342
# 5                  0.770558  0.640876
# 6                  0.770558  0.644976
# 7                  0.770558  0.648927
# 8                  0.770558  0.653356
# 9                  0.770558  0.657673
# 10                 0.770558  0.661257
# 11                 0.770558  0.664843
# 12                 0.770558  0.669557
# 13                 0.770558  0.674371
# 14                 0.770558  0.679004
# 15                 0.770558  0.683967
# 16                 0.770558  0.688807
# 17                 0.770558  0.694007
# 18                 0.770558  0.698899
# 19                 0.770558  0.703043
# 20                 0.770558  0.707844
# 21                 0.770558  0.712922
# 22                 0.770558  0.717367
# 23                 0.770558  0.721171
# 24                 0.770558  0.725487
# 25                 0.770558  0.728689
# 26                 0.770558  0.731578
# 27                 0.770558  0.732782

# %%
# make years integers

HDI['Year'] = HDI['Year'].astype(int)

# %%
HDI
# Out:
#     Year    Population  Life Expectancy Index  Education Expectancy Index  \
# 0   1990  2.276592e+07               0.699371                    0.449320
# 1   1991  2.313796e+07               0.702129                    0.450615
# 2   1992  2.349963e+07               0.704873                    0.457687
# 3   1993  2.385296e+07               0.707697                    0.463642
# 4   1994  2.420147e+07               0.710642                    0.470560
# 5   1995  2.454789e+07               0.713753                    0.478595
# 6   1996  2.489267e+07               0.717035                    0.485606
# 7   1997  2.523521e+07               0.720479                    0.492221
# 8   1998  2.557601e+07               0.724056                    0.499887
# 9   1999  2.591552e+07               0.727783                    0.507251
# 10  2000  2.625422e+07               0.731660                    0.512858
# 11  2001  2.659239e+07               0.735697                    0.518386
# 12  2002  2.693062e+07               0.739892                    0.526490
# 13  2003  2.726999e+07               0.744235                    0.534788
# 14  2004  2.761176e+07               0.748719                    0.542616
# 15  2005  2.795683e+07               0.753363                    0.551184
# 16  2006  2.830559e+07               0.758166                    0.559400
# 17  2007  2.865785e+07               0.763111                    0.568458
# 18  2008  2.901316e+07               0.768137                    0.576764
# 19  2009  2.937076e+07               0.773176                    0.583260
# 20  2010  2.972998e+07               0.778153                    0.591483
# 21  2011  3.009053e+07               0.782998                    0.600566
# 22  2012  3.045222e+07               0.787650                    0.608255
# 23  2013  3.081441e+07               0.792060                    0.614542
# 24  2014  3.117642e+07               0.796191                    0.622396
# 25  2015  3.153755e+07               0.799989                    0.627679
# 26  2016  3.189749e+07               0.803433                    0.632451
# 27  2017  3.225577e+07               0.806567                    0.633110
#
#     Income Expectancy Index       HDI
# 0                  0.770558  0.623289
# 1                  0.770558  0.624706
# 2                  0.770558  0.628774
# 3                  0.770558  0.632332
# 4                  0.770558  0.636342
# 5                  0.770558  0.640876
# 6                  0.770558  0.644976
# 7                  0.770558  0.648927
# 8                  0.770558  0.653356
# 9                  0.770558  0.657673
# 10                 0.770558  0.661257
# 11                 0.770558  0.664843
# 12                 0.770558  0.669557
# 13                 0.770558  0.674371
# 14                 0.770558  0.679004
# 15                 0.770558  0.683967
# 16                 0.770558  0.688807
# 17                 0.770558  0.694007
# 18                 0.770558  0.698899
# 19                 0.770558  0.703043
# 20                 0.770558  0.707844
# 21                 0.770558  0.712922
# 22                 0.770558  0.717367
# 23                 0.770558  0.721171
# 24                 0.770558  0.725487
# 25                 0.770558  0.728689
# 26                 0.770558  0.731578
# 27                 0.770558  0.732782

# %%
# plot HDI against years

a,b = np.polyfit(HDI['Year'], HDI['HDI'], 1)

plt.scatter(HDI['Year'], HDI['HDI'])
plt.plot(HDI['Year'], a* HDI['Year'] + b, "r")
plt.title('Year vs Global HDI')
plt.xlabel('Year')
plt.ylabel('HDI')
plt.show()

# %%
# plot Popultion against years

c,d = np.polyfit(HDI['Year'], HDI['Population'], 1)

plt.scatter(HDI['Year'], HDI['Population'])
plt.plot(HDI['Year'], c * HDI['Year'] + d, "r")
plt.title('Year vs Population')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
# line of best fit to confirm 2017
hdi_2017 = a * 2017 + b
print("hdi_2017: ", hdi_2017)

# use line of best fit to project hdi of 2122
hdi_2122 = a * 2122 + b
print("hdi_2122: ", hdi_2122)

# line of best fit to confirm population of 2017
population_2017 = c * 2017 + d
print("population_2017: ", population_2017)

#use line of best fit to project population of 2122
population_2122 = c * 2122 + d
print("population_2122: ", population_2122)
# Out:
# hdi_2017:  0.7368238701052707
# hdi_2122:  1.1935525991704932
# population_2017:  32193267.357795477
# population_2122:  68823463.68172145
